# %% [markdown]
# Import numpy and pandas.

# %%
import pandas as pd
import numpy as np

from datetime import datetime

# %% [markdown]
# Using the bash magic command, view the list of files inside of the data directory.

# %%
# 
# %ls data/
# Out:
# ActiveFile-Wilm1thru8-20191015.csv
# DE-VoterFile-Documentation 20171010.pdf
# locations/

# %%
#
df=pd.read_csv("data/ActiveFile-Wilm1thru8-20191015.csv", low_memory=False)

# %% [markdown]
# Load the csv file into a Pandas DataFrame.

# %%
#
print(df.columns)
# Out:
# Index(['UNIQUE-ID', 'LAST-NAME', 'FIRST-NAME', 'MID-INIT', 'SUFFIX',
#        'YEAR-OF-BIRTH', 'HOME-NO', 'HOME-APT', 'HOME-STREET', 'HOME-DEV',
#        'HOME-CITY', 'HOME-ZIPCODE', 'COUNTY', 'ED', 'RD', 'SD', 'CNLEVY',
#        'WILM', 'CODE-HOME-CITY', 'SCH-DIST', 'PARTY', 'DATE-REG', 'PP-HIST-1',
#        'PP-HIST-2', 'PR-HIST-1', 'PR-HIST-2', 'PR-HIST-3', 'GEN-HIST-1',
#        'GEN-HIST-2', 'GEN-HIST-3', 'GEN-HIST-4', 'GEN-HIST-5', 'SP-HIST-1',
#        'SP-HIST-2', 'SP-HIST-3', 'SCHL-HIST-1', 'SCHL-HIST-2', 'SCHL-HIST-3',
#        'SCHL-HIST-4', 'SCHL-HIST-5', 'REF-HIST-1', 'REF-HIST-2', 'REF-HIST-3',
#        'REF-HIST-4', 'REF-HIST-5', 'MAIL-NO', 'MAIL-APT', 'MAIL-STR',
#        'MAIL-CITY', 'MAIL-STATE', 'MAIL-ZIP', 'DATE-LAST-CHG', 'CODE-CHANGE',
#        'STATUS'],
#       dtype='object')

# %% [markdown]
# Display a list of columns in the DataFrame.

# %%
#
print(df.shape)
# Out:
# (51909, 54)

# %% [markdown]
# What is the shape of this DataFrame? How many columns does each row have? How many rows are there?

# %%
# 
grouped_zc=df.groupby('HOME-ZIPCODE')

# %% [markdown]
# # HOME ZIP CODE

# %% [markdown]
# Group objects using the HOME-ZIPCODE column. Assign the value to a variable called grouped_zc.
# [Pandas Groupby User Guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html)

# %%
#
print(type(grouped_zc))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %% [markdown]
# What type of object is grouped_zc?

# %%
#  
print(grouped_zc.groups)
# Out:
# {19801: [0, 1, 10, 12, 13, 15, 16, 20, 24, 34, 55, 56, 57, 58, 62, 64, 65, 67, 79, 92, 94, 95, 98, 102, 103, 110, 118, 120, 121, 129, 131, 136, 146, 149, 151, 157, 158, 173, 174, 180, 184, 188, 194, 197, 198, 202, 203, 210, 211, 215, 222, 223, 228, 229, 233, 241, 242, 263, 278, 281, 282, 284, 285, 286, 287, 288, 291, 292, 293, 294, 300, 301, 302, 310, 311, 312, 316, 317, 321, 322, 323, 324, 327, 333, 334, 336, 337, 339, 340, 343, 344, 345, 346, 347, 348, 349, 354, 357, 365, 372, ...], 19802: [3, 5, 11, 21, 29, 30, 31, 38, 39, 40, 45, 46, 51, 52, 53, 54, 59, 60, 61, 68, 69, 70, 76, 77, 78, 80, 84, 85, 88, 89, 91, 97, 99, 100, 101, 108, 109, 116, 122, 123, 124, 125, 130, 134, 135, 138, 139, 140, 143, 144, 145, 148, 154, 155, 156, 160, 162, 163, 172, 181, 186, 187, 195, 196, 200, 201, 205, 206, 207, 208, 213, 214, 220, 225, 226, 239, 240, 243, 245, 246, 250, 251, 252, 265, 270, 273, 275, 276, 277, 290, 299, 307, 308, 309, 313, 314, 315, 318, 319, 320, ...], 19805: [4, 6, 7, 8, 14, 17, 1
# ...

# %% [markdown]
# DataFrameGroupBy objects contain a groups attribute. Display the value of the groups attribute belonging to the grouped_zc object.

# %%
# 
print(grouped_zc.size())
# Out:
# HOME-ZIPCODE
# 19801    10730
# 19802    17182
# 19805    15548
# 19806     8326
# 19807      123
# dtype: int64

# %% [markdown]
# Invoke the size method on the grouped_zc object to find out how many items are associated with each zip code.

# %%
# 
# %matplotlib inline

import matplotlib.pyplot as plt

# %% [markdown]
# Use a magic command so that matplotlib graphics will display inline.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %% [markdown]
# Create a pie chart illustrating the number of voters per zip code.

# %%
# # 
grouped_zc = df.groupby('HOME-ZIPCODE')
plt.figure(figsize=(10, 6))
plt.title('Registered Voters by Zip Code')
t.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()  
zip_counts = grouped_zc.size()
plt.pie(zip_counts, labels=zip_counts.index, autopct='%1.1f%%')
plt.title('Number of Voters per Zip Code')
# Out:
# Text(0.5, 1.0, 'Number of Voters per Zip Code')

# %% [markdown]
# # YEAR OF BIRTH

# %% [markdown]
# Group objects by the YEAR-OF-BIRTH column. Assign the value to an object called "grouped_yob".

# %%
# 
grouped_yob=df.groupby('YEAR-OF-BIRTH')

# %% [markdown]
# Display the value of the groups attribute belonging the grouped_yob object.

# %%
# 
print(grouped_yob.groups)
# Out:
# {1900: [49249], 1912: [5607], 1915: [6983, 7233], 1916: [2773, 16265, 49808], 1917: [2425, 12614], 1918: [7276, 7318, 9601, 14196], 1919: [12435, 17404, 22219, 23508, 42509], 1920: [271, 350, 534, 3468, 3541, 3909, 5485, 5606, 7071, 13684, 14831, 15495, 17447, 22093, 24793, 24934, 26266, 27799, 37052, 37182, 38014, 42055, 47857], 1921: [977, 1048, 1905, 3326, 4066, 7893, 12729, 14907, 16396, 17176, 18116, 18736, 22236, 23100, 24936, 25142, 25335, 25632, 26505, 26592, 28858, 37963, 39804, 41209, 48463, 49695], 1922: [159, 3071, 3299, 4044, 4159, 6558, 9461, 13850, 16113, 16180, 16239, 18005, 20665, 22237, 25317, 30000, 32684, 35901, 37097, 37382, 40184, 41698, 44190, 48984, 49009, 49388, 49791, 50729, 51237], 1923: [5, 1846, 2795, 3753, 4129, 4308, 5505, 6225, 7259, 13599, 14331, 14650, 15951, 16891, 18223, 18380, 22277, 22323, 25012, 25356, 25474, 25523, 31360, 33616, 39803, 41074, 41576, 41661, 41917, 42635, 43422, 49213], 1924: [426, 766, 1311, 1446, 2011, 2461, 2691, 4064, 4106, 5
# ...

# %% [markdown]
# Select the object for the row indicating that the voter was born in 1900.

# %%
# 

df_1900 = df[df['YEAR-OF-BIRTH'] == 1900]
print(df_1900)
# Out:
#        UNIQUE-ID LAST-NAME FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH HOME-NO  \
# 49249  101092654   KENNEDY     JORDAN        D    NaN           1900     724
#
#       HOME-APT     HOME-STREET HOME-DEV  ... REF-HIST-5  MAIL-NO MAIL-APT  \
# 49249      NaN  N BANCROFT PKY      NaN  ...        NaN      NaN      NaN
#
#        MAIL-STR  MAIL-CITY  MAIL-STATE  MAIL-ZIP  DATE-LAST-CHG CODE-CHANGE  \
# 49249       NaN        NaN         NaN       NaN       20170731          P6
#
#       STATUS
# 49249      I
#
# [1 rows x 54 columns]

# %% [markdown]
# Graph a histogram to  illustrate the age distribution of voters in this dataset. Ty using different values for the bins attribute of the histogram.

# %%
# 
df['AGE']=datetime.now().year-df['YEAR-OF-BIRTH']
# Plot histogram and show percentages for each age range
counts, bins, patches = plt.hist(df['AGE'], bins=20, edgecolor='black')
total = counts.sum()
for count, bin_left, bin_right in zip(counts, bins[:-1], bins[1:]):
    percent = (count / total) * 100
    plt.text((bin_left + bin_right) / 2, count, f'{percent:.1f}%', ha='center', va='bottom', fontsize=8)
plt.xlabel('Age')
plt.ylabel('Number of Voters')
plt.title('Age Distribution of Voters')
# Create a DataFrame associating each age bin with its percentage
age_bin_labels = [f"{int(left)}-{int(right)}" for left, right in zip(bins[:-1], bins[1:])]
percentages = [(count / total) * 100 for count in counts]
age_distribution = pd.DataFrame({
    'Age Range': age_bin_labels,
    'Percentage': percentages,
    'Count': counts
})
age_distribution['Percentage'] = age_distribution['Percentage'].round(3)
print(age_distribution)
plt.show()
# Out:
#    Age Range  Percentage   Count
# 0      23-28       7.673  3983.0
# 1      28-33       9.565  4965.0
# 2      33-38      12.067  6264.0
# 3      38-43      10.360  5378.0
# 4      43-48       8.973  4658.0
# 5      48-53       6.980  3623.0
# 6      53-58       7.756  4026.0
# 7      58-63       8.226  4270.0
# 8      63-68       8.008  4157.0
# 9      68-74       6.718  3487.0
# 10     74-79       5.893  3059.0
# 11     79-84       3.227  1675.0
# 12     84-89       2.098  1089.0
# 13     89-94       1.356   704.0
# 14     94-99       0.697   362.0
# 15    99-104       0.324   168.0
# 16   104-109       0.071    37.0
# 17   109-114       0.006     3.0
# 18   114-119       0.000     0.0
# 19   119-125       0.002     1.0

# %% [markdown]
# # PARTY

# %% [markdown]
# Group objects using the PARTY column. Assign the value to a variable called grouped_p.

# %%
# 
grouped_p=df.groupby('PARTY')

# %% [markdown]
# Display the value of the groups attribute belonging to the grouped_p object.

# %%
# 
print(grouped_p.groups)
# Out:
# {'A': [2578, 2639, 3108, 5105, 10230, 10491, 10842, 11620, 12162, 12413, 12417, 12454, 12507, 12522, 12810, 12831, 14469, 14507, 15144, 15382, 15509, 16858, 17075, 17173, 17309, 19466, 19884, 20846, 21086, 21459, 22451, 22645, 22746, 23739, 24604, 24664, 24665, 24691, 26662, 28775, 30455, 30510, 30976, 34065, 34903, 36518, 44984, 45851, 46837, 49699, 51736, 51830], 'B': [11866, 11867, 11869, 11870, 11873, 11875, 11876, 11880, 11882, 11883, 11884, 11885, 11886, 11887, 11888, 11889, 11890, 11891, 11892, 11893, 11895, 11896, 11898, 11899, 11900, 11901, 11902, 11903, 11904, 11905, 11906, 11908, 11909, 11910, 11911, 11913, 11914, 11915, 11916, 11917, 11918, 11920, 11924, 11925, 11926, 11927, 11929, 11930, 11932, 11933, 11934, 11940, 11941, 11942, 11951, 11952, 11953, 11956, 11958, 11960, 11961, 11965, 11966, 11968, 11971, 11973, 11974, 11977, 11980, 11981, 11982, 11984, 11987, 11988, 11990, 11991, 11992, 11994, 11999, 12001, 12002, 12003, 12004, 12006, 12008, 12009, 12012, 12014, 12015, 1
# ...

# %% [markdown]
# Invoke the size method on the grouped_p object to find out how many items are associated with each party.

# %%
# 
print(grouped_p.size())
# Out:
# PARTY
# A       52
# B      441
# D    38020
# E       30
# G       42
# H       82
# I     7670
# J      161
# L       98
# M        1
# O       33
# Q       17
# R     4851
# T       14
# V       11
# W      333
# Y       14
# Z       39
# dtype: int64

# %% [markdown]
# Create a bar chart to visualize the number of voters associated with each party.

# %%
# 
grouped_p_count=grouped_p['YEAR-OF-BIRTH'].count()
grouped_p_count_bar = grouped_p_count.plot.bar()
plt.title('Number of Voters by Party')
plt.xlabel('Party')
plt.ylabel('Number of Voters')
plt.xticks(rotation=45)
plt.tight_layout()
# Add a legend box with party names
party_names = {
    'A': 'American',
    'B': 'Blue',
    'D': 'Democratic',
    'E': 'Equality',
    'G': 'Green',
    'H': 'Humanist',
    'I': 'Independent',
    'J': 'Justice',
    'L': 'Libertarian',
    'M': 'Moderate',
    'O': 'Other',
    'Q': 'Quality',
    'R': 'Republican',
    'T': 'Tea',
    'V': 'Veterans',
    'W': 'Workers',
    'Y': 'Youth',
    'Z': 'Zebra'
}
# Add percentage of voters on top of the bars
total_voters = grouped_p_count.sum()
for idx, value in enumerate(grouped_p_count):
    percent = value / total_voters * 100
    grouped_p_count_bar.text(idx, value, f'{percent:.1f}%', ha='center', va='bottom', fontsize=9)
# Create legend handles
handles = [plt.Line2D([0], [0], color='none', label=f"{k}: {v}") for k, v in party_names.items() if k in grouped_p_count.index]
plt.legend(handles=handles, title="Party Codes", loc='upper right', bbox_to_anchor=(1.35, 1))

# %% [markdown]
# # Merging Two DataFrames

# %% [markdown]
# Using the data from the documentation, create a Pandas DataFrame that contains the party code and the corresponding legal name for each party.

# %%
# legal_names = {}

legal_names = {
    "party_codes": ["A", "B", "D", "E", "G", "H", "I", "J", "L", "M", "O", "Q", "R", "T", "V", "W", "Y", "Z"],
    "party_names": ["AMERICAN", "AMERICAN DELTA", "DEMOCRATIC PARTY", "LIBERAL", "NON PARTISAN", "GREEN PARTY",
                    "UNAFFILIATED", "WORKING FAMILIES PARTY", "LIBERTARIAN PARTY", "REFORM PARTY",
                    "OTHERS/ALL OTHER PARTIES", "CONSTITUTION PARTY", "REPUBLICAN PARTY", "CONSERVATIVE",
                    "NATURAL LAW PARTY", "INDEPENDENT PARTY OF DEL", "THE BLUE ENIGMA PARTY", "SOCIALIST WORKERS PARTY"]
}

# %%
df_legal_names = pd.DataFrame(legal_names)

# %%
df_legal_names
# Out:
#    party_codes               party_names
# 0            A                  AMERICAN
# 1            B            AMERICAN DELTA
# 2            D          DEMOCRATIC PARTY
# 3            E                   LIBERAL
# 4            G              NON PARTISAN
# 5            H               GREEN PARTY
# 6            I              UNAFFILIATED
# 7            J    WORKING FAMILIES PARTY
# 8            L         LIBERTARIAN PARTY
# 9            M              REFORM PARTY
# 10           O  OTHERS/ALL OTHER PARTIES
# 11           Q        CONSTITUTION PARTY
# 12           R          REPUBLICAN PARTY
# 13           T              CONSERVATIVE
# 14           V         NATURAL LAW PARTY
# 15           W  INDEPENDENT PARTY OF DEL
# 16           Y     THE BLUE ENIGMA PARTY
# 17           Z   SOCIALIST WORKERS PARTY

# %% [markdown]
# Create a Pandas DataFrame that contains the Party code and the corresponding number of registered voters for said party.

# %%
# Create DataFrame df_party_counts here 
df_party_counts = pd.DataFrame({
    'Party Code': grouped_p_count.index,
    'Number of Voters': grouped_p_count.values
})  
df_party_counts 
df_party_counts['Party Name'] = df_party_counts['Party Code'].map(dict(zip(legal_names['party_codes'], legal_names['party_names'])))
df_party_counts = df_party_counts[['Party Code', 'Party Name', 'Number of Voters']]
df_party_counts = df_party_counts.sort_values(by='Number of Voters', ascending=False)
df_party_counts.reset_index(drop=True, inplace=True)

# %%
# df_party_counts 
df_party_counts
# Out:
#    Party Code                Party Name  Number of Voters
# 0           D          DEMOCRATIC PARTY             38020
# 1           I              UNAFFILIATED              7670
# 2           R          REPUBLICAN PARTY              4851
# 3           B            AMERICAN DELTA               441
# 4           W  INDEPENDENT PARTY OF DEL               333
# 5           J    WORKING FAMILIES PARTY               161
# 6           L         LIBERTARIAN PARTY                98
# 7           H               GREEN PARTY                82
# 8           A                  AMERICAN                52
# 9           G              NON PARTISAN                42
# 10          Z   SOCIALIST WORKERS PARTY                39
# 11          O  OTHERS/ALL OTHER PARTIES                33
# 12          E                   LIBERAL                30
# 13          Q        CONSTITUTION PARTY                17
# 14          T              CONSERVATIVE                14
# ...

# %% [markdown]
# Merge the two DataFrames.

# %%
# Merge DataFrame here 
df_merged = pd.merge(df_party_counts, df_legal_names, left_on='Party Code', right_on='party_codes', how='left')
df_merged = df_merged[['Party Code', 'Party Name', 'Number of Voters', 'party_names']]
df_merged.columns = ['Party Code', 'Party Name', 'Number of Voters', 'Party Names']
df_merged = df_merged.sort_values(by='Number of Voters', ascending=False)
df_merged.reset_index(drop=True, inplace=True)

# %%
# Display new DataFrame here 
df_merged
# Out:
#    Party Code                Party Name  Number of Voters  \
# 0           D          DEMOCRATIC PARTY             38020
# 1           I              UNAFFILIATED              7670
# 2           R          REPUBLICAN PARTY              4851
# 3           B            AMERICAN DELTA               441
# 4           W  INDEPENDENT PARTY OF DEL               333
# 5           J    WORKING FAMILIES PARTY               161
# 6           L         LIBERTARIAN PARTY                98
# 7           H               GREEN PARTY                82
# 8           A                  AMERICAN                52
# 9           G              NON PARTISAN                42
# 10          Z   SOCIALIST WORKERS PARTY                39
# 11          O  OTHERS/ALL OTHER PARTIES                33
# 12          E                   LIBERAL                30
# 13          Q        CONSTITUTION PARTY                17
# 14          T              CONSERVATIVE                14
# ...

# %% [markdown]
# Create a bar graph again but using the legal name for each party as the value on the x axes.

# %%
# Display the histogram
plt.figure(figsize=(10, 6))
plt.bar(df_merged['Party Name'], df_merged['Number of Voters'], color='skyblue')
plt.title('Number of Voters by Party in Wilmington, DE')
plt.xlabel('Party Name')            
plt.ylabel('Number of Voters')
plt.xticks(rotation=45)
# Add percentage of voters on top of the bars
total_voters = df_merged['Number of Voters'].sum()
for idx, value in enumerate(df_merged['Number of Voters']):
    percent = value / total_voters * 100
    # Place the text above the bar, horizontally, and adjust if bars are close
    plt.text(idx, value + max(df_merged['Number of Voters']) * 0.01, f'{percent:.1f}%', 
             ha='center', va='bottom', fontsize=9, rotation=0)
# If x labels overlap, adjust bottom margin or use tight_layout
# Check for error in the party names under the bars
# The x-axis labels should match the 'Party Name' column in df_merged and be aligned with the bars.
# If the labels are not aligned, it may be due to matplotlib's default behavior with long or similar names.
# To ensure correct alignment, explicitly set the x-ticks and labels:

plt.xticks(ticks=range(len(df_merged['Party Name'])), labels=df_merged['Party Name'], rotation=45, ha='right')
plt.tight_layout(rect=[0, 0.2, 1, 1])  # Add bottom margin for x labels
